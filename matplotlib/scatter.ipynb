# %% [markdown]
# # Scatter Plot
# *Creating scatter plot*
# * with pyplot,You can use the scatter() function to drow a scatter plot.
# * The scatter() function plot one dot for each observation .It need 2 array of the same length ,one for the value of the x-axis and one for value on the y-axis

# %%
# A simple scatter plot
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,6,7,5,3,2,5])
y = np.array([99,55,66,7,77,88,55])
plt.scatter(x,y)

# The observation in the example above is the result of 13 cars passing by.
# The X-axis shows how old the car is.
# The Y-axis shows the speed of the car when it passes.
# Are there any relationships between the observations?
# It seems that the newer the car, the faster it drives, but that could be a
# coincidence, after all we only registered 13 cars.

# %% [markdown]
# # Compare plot
# * In the example above,there seems to be a relationship b/w speed and age ,but what if we plot the observation from another day as well? will the scatter plot tell us somethings else:

# %%
# The day one ,the speed and age of the car
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x,y)
# the day second , the speed and age of the car
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,8])
plt.scatter(x,y)   # Changing color color = "colorname" eg "rgb"
plt.show()

# %% [markdown]
# *Set own color for each scatter plot with the color of c argument*

# %%
# Set the own color of the markers:
plt.scatter(x,y,color = 'r')
plt.scatter(x,y,color = 'g')
plt.show()

# %% [markdown]
# *Color Each Dots*

# %%
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x,y, c = colors)

# %% [markdown]
# # ColorMap
# * The Matplotlib module has a number of available colormaps.
# * A colormap is like a list of colors, where each color has a value of that ranges from 100.
# * The colormap is called *Viridis* and you can see it range from which is a purple color up to 100,which is a yellow color.
# # How to use
# * We can specify the colormap with the keyword argument cmap with the value of colormap ,in this case *viridis* in which is one of the build-in colormap available in colormap
# * In addition you have to create an array with values (from 0 to 100), one value for each point in the scatter plot:

# %%
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0,10,20,30,40,45,50,60,70,80,85,90,100])
plt.scatter(x,y,c = colors,cmap='viridis')  # cmap (colormap) have multiple type of colormap type
plt.colorbar()   # With the help of colorbor add a colorbar in the chart

# %% [markdown]
# # Size of scatter
# * set your own size for the marker

# %%
sizes = np.array([20,50,100,200,500,1000,60,90,10,300,600,800,75])
plt.scatter(x,y, c = colors,cmap='viridis',s = sizes)

# %% [markdown]
# # Alpha
# * You can adjest the transparency of the dots with the alpha argument.
# * just like color, make sure  the array of size has a same length as the arrays for the x and y-axis:

# %%
plt.scatter(x,y,c= colors,cmap='viridis',s = sizes,alpha=0.5)

# %% [markdown]
# # Combine Color size and Alpha
# * You can combine a colormap with diffrent sizes of the dots. this is best visulazed of the dots are transparent.

# %%
x = np.random.randint(100,size=(100))
y = np.random.randint(100,size=(100))
color = np.random.randint(100,size=(100))
size = 10*np.random.randint(100,size=(100))
plt.scatter(x,y,c = color,s = size,alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
