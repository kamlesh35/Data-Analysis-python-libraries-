# %%
import pandas as pd

# %% [markdown]
# # Read JSON

# %% [markdown]
# Big data sets are often stored, or extracted as JSON.
#
# JSON is plain text, but has the format of an object, and is well known in the world of programming, including Pandas.

# %%
df = pd.read_json("Json.file")
df
# Out:
# C:\Users\kk919\AppData\Local\Temp\ipykernel_12176\4266942046.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json("Json.file")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kk919\Desktop\Python Library\Pandas\JSONpd.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kk919/Desktop/Python%20Library/Pandas/JSONpd.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> df = pd.read_json("Json.file")
#       <a href='vscode-notebook-cell:/c%3A/Users/kk919/Desktop/Python%20Library/Pandas/JSONpd.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> df
#
# File c:\Users\kk919\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:804, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     802     return json_reader
#     803 else:
# --> 804     return json_reader.read()
#
# File c:\Users\kk919\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:1014, in JsonReader.read(self)
#    1012         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1013 else:
# -> 1014     obj = self._get_object_parser(self.data)
#    1015 if self.dtype_backend is not lib.no_default:
#    1016     return obj.convert_dtypes(
#    1017         infer_objects=False, dtype_backend=self.dtype_backend
#    1018     )
#
# File c:\Users\kk919\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:1040, in JsonReader._get_object_parser(self, json)
#    1038 obj = None
#    1039 if typ == "frame":
# -> 1040     obj = FrameParser(json, **kwargs).parse()
#    1042 if typ == "series" or obj is None:
#    1043     if not isinstance(dtype, bool):
#
# File c:\Users\kk919\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:1173, in Parser.parse(self)
#    1172 def parse(self):
# -> 1173     self._parse()
#    1175     if self.obj is None:
#    1176         return None
#
# File c:\Users\kk919\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\json\_json.py:1366, in FrameParser._parse(self)
#    1362 orient = self.orient
#    1364 if orient == "columns":
#    1365     self.obj = DataFrame(
# -> 1366         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1367     )
#    1368 elif orient == "split":
#    1369     decoded = {
#    1370         str(k): v
#    1371         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1372     }
#
# ValueError: Expected object or value

# %% [markdown]
# If your JSON code is not in a file, but in a Python Dictionary, you can load it into a DataFrame directly

# %%
data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130       409
# 1        60    117       145       479
# 2        60    103       135       340
# 3        45    109       175       282
# 4        45    117       148       406
# 5        60    102       127       300

# %% [markdown]
# # Pandas Analysis DataFrame

# %%
# Viewing the data in csv file....
df = pd.read_csv("C:\\Users\\kk919\\Desktop\\payment.csv")
df.head(10)
# Out:
#    ID       Mode  amout  year
# 0    1     paytm   2000  2001
# 1    3      gpay   3000  2002
# 2    5  whatsapp   3000  2003
# 3    7     kotak   4000  2005
# 4    9     ICICI   5000  2006
# 5   10  phonepay   6000  2004
# 6   22     paytm   5000  2009
# 7   25     ICICI   5000  2008
# 8   26      gpay   9000  2012
# 9   32     paytm   8000  2009

# %%
df.head()
# Out:
#    ID       Mode  amout  year
# 0    1     paytm   2000  2001
# 1    3      gpay   3000  2002
# 2    5  whatsapp   3000  2003
# 3    7     kotak   4000  2005
# 4    9     ICICI   5000  2006

# %%
df.tail()
# Out:
#     ID       Mode  amout  year
# 11   76    airtel   6000  2016
# 12   89      gpay   8000  2019
# 13   90  phonepay   7800  2012
# 14  100     kotak   6000  2023
# 15  102  whatsapp   9000  2023
